# %% [markdown]
# <a href="https://colab.research.google.com/github/SaifEleslamElgalaly/food-101-classification/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /content/
# Out:
# drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/"
# Out:
#  Classroom  'Colab Notebooks'  '(DCP-683-230923-1958) Saif eleslam elgalaly.pdf'   food-101

# %%
# !ls "/content/drive/My Drive/food-101"
# Out:
# images	license_agreement.txt  meta  README.txt

# %%
# !rm -rf "/content/dataset"  # حذف أي بقايا قديمة
# !ln -s "/content/drive/My Drive/food-101" "/content/dataset"

# %%
# !ls "/content/dataset"
# Out:
# images	license_agreement.txt  meta  README.txt

# %%
# !ls "/content/dataset/images"
# Out:
# apple_pie	    crab_cakes		     gyoza		    poutine
# baby_back_ribs	    creme_brulee	     hamburger		    prime_rib
# baklava		    croque_madame	     hot_and_sour_soup	    pulled_pork_sandwich
# beef_carpaccio	    cup_cakes		     hot_dog		    ramen
# beef_tartare	    deviled_eggs	     huevos_rancheros	    ravioli
# beet_salad	    donuts		     hummus		    red_velvet_cake
# beignets	    dumplings		     ice_cream		    risotto
# bibimbap	    edamame		     lasagna		    samosa
# bread_pudding	    eggs_benedict	     lobster_bisque	    sashimi
# breakfast_burrito   escargots		     lobster_roll_sandwich  scallops
# bruschetta	    falafel		     macaroni_and_cheese    seaweed_salad
# caesar_salad	    filet_mignon	     macarons		    shrimp_and_grits
# cannoli		    fish_and_chips	     miso_soup		    spaghetti_bolognese
# caprese_salad	    foie_gras		     mussels		    spaghetti_carbonara
# carrot_cake	    french_fries	     nachos		    spring_rolls
# ...

# %%
# !find "/content/dataset/images" -type f | wc -l
# Out:
# 101000

# %%
dataset_path = "/content/drive/My Drive/food-101"

# %%
dataset_path = "/content/drive/My Drive/food-101"
local_dataset_path = "/content/Food101_copy"

import os

if os.path.exists(dataset_path):
    print("📂 Copying dataset... This may take some time ⏳")
    # !rsync -ah --progress "{dataset_path}/" "{local_dataset_path}/"
    print("✔️ Dataset copied successfully!")
else:
    print(f"❌ Error: The directory '{dataset_path}' does not exist. Please check the path.")
# Out:
# Streaming output truncated to the last 5000 lines.
# images/baby_back_ribs/2741921.jpg
#          69.78K 100%   73.99kB/s    0:00:00 (xfr#1530, ir-chk=1472/3106)
# images/baby_back_ribs/2753490.jpg
#          44.72K 100%   11.39MB/s    0:00:00 (xfr#1531, ir-chk=1471/3106)
# images/baby_back_ribs/275366.jpg
#          40.96K 100%  120.47kB/s    0:00:00 (xfr#1532, ir-chk=1470/3106)
# images/baby_back_ribs/2764727.jpg
#          46.95K 100%   73.24kB/s    0:00:00 (xfr#1533, ir-chk=1469/3106)
# images/baby_back_ribs/2767083.jpg
#          62.98K 100%   63.40kB/s    0:00:00 (xfr#1534, ir-chk=1468/3106)
# images/baby_back_ribs/2769114.jpg
#          89.00K 100%   67.01kB/s    0:00:01 (xfr#1535, ir-chk=1467/3106)
# images/baby_back_ribs/2774533.jpg
#          62.94K 100%  176.62kB/s    0:00:00 (xfr#1536, ir-chk=1466/3106)
# images/baby_back_ribs/2780701.jpg
#          52.65K 100%   92.48kB/s    0:00:00 (xfr#1537, ir-chk=1465/3106)
# images/baby_back_ribs/2785758.jpg
# ...
